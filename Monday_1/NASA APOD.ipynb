# %%
import requests
import time
from IPython import display

api_key = "1NueOhCvDEbzaopMmweCQAdXizbD9dYvubUtapY8"

dates = ["2019-01-01","2018-01-02","2017-01-01","2016-01-01","1999-09-08"]

for date in dates:
    print(date)
    url = f'https://api.nasa.gov/planetary/apod?api_key={api_key}&date={date}'
    response = requests.get(url)
    image = response.json()["url"]
    display.clear_output()
    display.display(display.Image(image))
    time.sleep(1.5)
