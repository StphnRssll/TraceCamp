# %%
# from https://pypi.org/project/youtube-transcript-api/
from youtube_transcript_api import YouTubeTranscriptApi
YouTubeTranscriptApi.get_transcript("M2W-HPfvJ2w",languages=['en'])
# Out:
# [{'text': 'hmm excuse me come here come here hey',
#   'start': 1.19,
#   'duration': 5.439},
#  {'text': 'can I get a number one in this menu',
#   'start': 4.23,
#   'duration': 4.59},
#  {'text': 'please yes yes yes number one just',
#   'start': 6.629,
#   'duration': 3.811},
#  {'text': "number one that's all I got all right",
#   'start': 8.82,
#   'duration': 3.689},
#  {'text': "hey everybody today's video we're going",
#   'start': 10.44,
#   'duration': 4.98},
#  {'text': 'to be eating real food versus the fake',
#   'start': 12.509,
#   'duration': 4.35},
#  {'text': 'food version of it', 'start': 15.42, 'duration': 2.939},
#  {'text': "meaning they're gonna look really",
#   'start': 16.859,
#   'duration': 3.781},
#  {'text': "identical one of them is fake and it's",
#   'start': 18.359,
#   'duration': 5.01},
#  {'text': 'our job to figure out which one is fake',
#   'start': 20.64,
#   'duration': 5.459},
#  {'text': 'are you ready for this this is 24 hours',
# ...
